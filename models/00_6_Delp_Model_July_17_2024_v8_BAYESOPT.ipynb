# %%
import os
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from torch.utils.data import DataLoader, TensorDataset
import joblib
import tempfile
from ray import air, train
from ray.train import Checkpoint

import ray
from ray import tune
from ray.tune.schedulers import ASHAScheduler
from ray.tune.search.bayesopt import BayesOptSearch

class DelpNN(nn.Module):
    def __init__(self):
        super(DelpNN, self).__init__()
        self.fc1 = nn.Linear(6, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 64)
        self.fc4 = nn.Linear(64, 16)
        self.fc5 = nn.Linear(16, 1)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=0.5)

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.relu(self.fc2(x))
        x = self.dropout(x)
        x = self.relu(self.fc3(x))
        x = self.dropout(x)
        x = self.relu(self.fc4(x))
        x = self.dropout(x)
        x = self.fc5(x)
        return x

def load_and_prepare_data(filepath):
    try:
        data = pd.read_csv(filepath, delim_whitespace=True, comment='%', header=None)
        data.columns = ['HCC', 'WCC', 'LCC', 'Tamb', 'Uin', 'Q',
                        'Temperature1', 'Temperature2', 'Temperature3', 'Temperature4',
                        'Temperature5', 'Temperature6', 'Pressure1', 'Pressure2', 'Delp',
                        'Velocity1', 'Velocity2', 'Tsta', 'StackTemp2']
    except Exception as e:
        print(f"Error reading the data file: {e}")
        return None, None

    feature_labels = ['HCC', 'WCC', 'LCC', 'Tamb', 'Uin', 'Q']
    X = data[feature_labels]
    Y = data['Delp']
    return X, Y

def split_data(X, Y, test_size=0.2, random_state=42):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=test_size, random_state=random_state)
    return X_train, X_test, Y_train, Y_test

def preprocess_and_prepare_loaders(X_train, X_test, Y_train, Y_test, batch_size=64):
    scaler_X = StandardScaler()
    X_train_scaled = scaler_X.fit_transform(X_train)
    X_test_scaled = scaler_X.transform(X_test)
    joblib.dump(scaler_X, '6_scaler_X.pkl')

    X_train_tensor = torch.tensor(X_train_scaled, dtype=torch.float32)
    X_test_tensor = torch.tensor(X_test_scaled, dtype=torch.float32)
    Y_train_tensor = torch.tensor(Y_train.values, dtype=torch.float32).unsqueeze(1)
    Y_test_tensor = torch.tensor(Y_test.values, dtype=torch.float32).unsqueeze(1)

    train_dataset = TensorDataset(X_train_tensor, Y_train_tensor)
    test_dataset = TensorDataset(X_test_tensor, Y_test_tensor)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    return train_loader, test_loader

def train_model(config, checkpoint_dir=None, data_dir=None):
    model = DelpNN()
    criterion = nn.L1Loss()
    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=config["lr"],
        betas=(config["beta1"], config["beta2"]),
        eps=1e-08,
        weight_decay=config["weight_decay"],
    )
    
    if checkpoint_dir:
        model_state, optimizer_state = torch.load(os.path.join(checkpoint_dir, "checkpoint.pt"))
        model.load_state_dict(model_state)
        optimizer.load_state_dict(optimizer_state)

    train_loader, test_loader = data_dir

    best_loss = float('inf')
    epochs_no_improve = 0
    num_epochs = 1000  # Fixed number of epochs
    patience = 10     # Fixed patience value

    for epoch in range(num_epochs):
        running_loss = 0.0
        model.train()
        for inputs, labels in train_loader:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        model.eval()
        val_loss = sum(criterion(model(inputs), labels).item() for inputs, labels in test_loader) / len(test_loader)

        if val_loss < best_loss:
            best_loss = val_loss
            epochs_no_improve = 0
            with tempfile.TemporaryDirectory() as temp_checkpoint_dir:
                path = os.path.join(temp_checkpoint_dir, "checkpoint.pt")
                torch.save((model.state_dict(), optimizer.state_dict()), path)
                checkpoint = Checkpoint.from_directory(temp_checkpoint_dir)
                train.report({"loss": val_loss}, checkpoint=checkpoint)
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print(f'Early stopping after {epoch+1} epochs')
                break

        train.report({"loss": val_loss})
    
    print('Training complete.')

def evaluate_model(model, test_loader, criterion, filename='true_vs_predicted.png'):
    model.eval()
    total_loss = 0
    total_rmse = 0
    predictions, actuals = [], []

    with torch.no_grad():
        for inputs, labels in test_loader:
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            total_loss += loss.item() * inputs.size(0)
            outputs_np = outputs.detach().cpu().numpy()
            labels_np = labels.detach().cpu().numpy()
            rmse = mean_squared_error(labels_np, outputs_np, squared=False)
            total_rmse += rmse * labels.size(0)
            predictions.extend(outputs_np.flatten())
            actuals.extend(labels_np.flatten())

    mean_loss = total_loss / len(test_loader.dataset)
    mean_rmse = total_rmse / len(test_loader.dataset)
    relative_error = (mean_rmse / np.mean(actuals)) * 100
    r2 = r2_score(actuals, predictions)

    print(f'Test MSE: {mean_loss:.4f}')
    print(f'Test RMSE: {mean_rmse:.4f} Pa')
    print(f'Relative Error: {relative_error:.2f}%')
    print(f'R^2 Score: {r2:.4f}')

    rcParams['font.family'] = 'serif'
    rcParams['font.serif'] = ['Times New Roman']
    rcParams['font.size'] = 12
    plt.figure(figsize=(10, 5))
    plt.scatter(actuals, predictions, alpha=0.5)
    plt.plot([min(actuals), max(actuals)], [min(actuals), max(actuals)], 'k-', label='Ideal Line')
    plt.xlabel('True Pressure Drop')
    plt.ylabel('Predicted Pressure Drop')
    plt.grid(True)
    plt.savefig(filename, format='png', bbox_inches='tight')
    plt.show()
    
    return mean_rmse

def main():
    ray.init()

    filepath = '/Users/hanheelee/Desktop/Projects/00_ML_Fuel_Cell/Set 1.txt'
    X, Y = load_and_prepare_data(filepath)
    if X is None or Y is None:
        print("Failed to load data.")
        return

    X_train, X_test, Y_train, Y_test = split_data(X, Y)
    train_loader, test_loader = preprocess_and_prepare_loaders(X_train, X_test, Y_train, Y_test)

    data_dir = (train_loader, test_loader)

    search_space = {
        "lr": tune.loguniform(1e-5, 1e-3),
        "beta1": tune.uniform(0.5, 0.9),
        "beta2": tune.uniform(0.9, 0.999),
        "weight_decay": tune.loguniform(1e-6, 1e-2)
    }

    bayesopt = BayesOptSearch(metric="loss", mode="min")
    scheduler = ASHAScheduler()

    analysis = tune.run(
        tune.with_parameters(train_model, data_dir=data_dir),
        resources_per_trial={"cpu": 2, "gpu": 0},
        config=search_space,
        num_samples=100,
        scheduler=scheduler,
        search_alg=bayesopt,
        metric="loss",
        mode="min"
    )

    print("Best hyperparameters found were: ", analysis.get_best_config(metric="loss", mode="min"))

    best_trial = analysis.get_best_trial("loss", "min", "last")
    best_checkpoint = best_trial.checkpoint

    if best_checkpoint:
        with best_checkpoint.as_directory() as best_checkpoint_dir:
            model_state, optimizer_state = torch.load(os.path.join(best_checkpoint_dir, "checkpoint.pt"))

        best_model = DelpNN()
        best_model.load_state_dict(model_state)
        mean_rmse = evaluate_model(best_model, test_loader, nn.L1Loss())
        torch.save(best_model.state_dict(), f'Delp_{mean_rmse:.4f}.pth')
        print("Model and scalers are saved successfully.")
    else:
        print("No checkpoint found for the best trial.")

if __name__ == "__main__":
    torch.manual_seed(42)
    main()
# Out:
# 2024-07-22 18:33:22,553	INFO worker.py:1788 -- Started a local Ray instance.
# /var/folders/73/wzyp1fs57lg7p28crz696s_r0000gp/T/ipykernel_73079/3722613355.py:47: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(filepath, delim_whitespace=True, comment='%', header=None)
# 2024-07-22 18:33:24,078	INFO tune.py:616 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# 2024-07-22 18:33:24,095	WARNING bayesopt_search.py:431 -- BayesOpt does not support specific sampling methods. The LogUniform sampler will be dropped.
# 2024-07-22 18:33:24,095	WARNING bayesopt_search.py:431 -- BayesOpt does not support specific sampling methods. The LogUniform sampler will be dropped.
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-07-22 18:40:29</td></tr>
# <tr><td>Running for: </td><td>00:07:05.14        </td></tr>
# <tr><td>Memory:      </td><td>10.6/16.0 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=93<br>Bracket: Iter 64.000: -37.65944687525431 | Iter 16.000: -76.28391075134277 | Iter 4.000: -150.28291479746503 | Iter 1.000: -327.53591982523596<br>Logical resource usage: 2.0/12 CPUs, 0/0 GPUs
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name          </th><th>status    </th><th>loc            </th><th style="text-align: right;">   beta1</th><th style="text-align: right;">   beta2</th><th style="text-align: right;">         lr</th><th style="text-align: right;">
# <tr><td>train_model_2049de82</td><td style="text-align: right;">475.273 </td><td>True               </td></tr>
# <tr><td>train_model_2191c4fe</td><td style="text-align: right;">196.178 </td><td>                   </td></tr>
# <tr><td>train_model_21d7f317</td><td style="text-align: right;">355.343 </td><td>True               </td></tr>
# <tr><td>train_model_24b43512</td><td style="text-align: right;">380.144 </td><td>                   </td></tr>
# <tr><td>train_model_25686466</td><td style="text-align: right;">472.069 </td><td>True               </td></tr>
# <tr><td>train_model_25bc0192</td><td style="text-align: right;">421.787 </td><td>True               </td></tr>
# <tr><td>train_model_26ece057</td><td style="text-align: right;">160.318 </td><td>                   </td></tr>
# <tr><td>train_model_2b039a13</td><td style="text-align: right;"> 76.3686</td><td>                   </td></tr>
# <tr><td>train_model_2b407e3b</td><td style="text-align: right;">151.355 </td><td>                   </td></tr>
# <tr><td>train_model_2c769345</td><td style="text-align: right;">475.185 </td><td>True               </td></tr>
# <tr><td>train_model_3541cb1d</td><td style="text-align: right;">362.974 </td><td>True               </td></tr>
# <tr><td>train_model_37a9b4d6</td><td style="text-align: right;">475.081 </td><td>True               </td></tr>
# <tr><td>train_model_385955ad</td><td style="text-align: right;">468.599 </td><td>True               </td></tr>
# <tr><td>train_model_390dac39</td><td style="text-align: right;">445.571 </td><td>True               </td></tr>
# <tr><td>train_model_446cd54b</td><td style="text-align: right;"> 77.9265</td><td>                   </td></tr>
# <tr><td>train_model_45df990b</td><td style="text-align: right;">354.623 </td><td>True               </td></tr>
# <tr><td>train_model_544135fc</td><td style="text-align: right;"> 55.5185</td><td>                   </td></tr>
# <tr><td>train_model_55315b8a</td><td style="text-align: right;">383.893 </td><td>True               </td></tr>
# <tr><td>train_model_5afba531</td><td style="text-align: right;">193.665 </td><td>                   </td></tr>
# <tr><td>train_model_5b09acaf</td><td style="text-align: right;"> 84.5021</td><td>True               </td></tr>
# <tr><td>train_model_5f41ba04</td><td style="text-align: right;"> 88.4023</td><td>                   </td></tr>
# <tr><td>train_model_6070359d</td><td style="text-align: right;">470.275 </td><td>True               </td></tr>
# <tr><td>train_model_61270c51</td><td style="text-align: right;">467.846 </td><td>True               </td></tr>
# <tr><td>train_model_68d0d1d6</td><td style="text-align: right;">471.227 </td><td>True               </td></tr>
# <tr><td>train_model_6d2986ce</td><td style="text-align: right;">339.032 </td><td>True               </td></tr>
# <tr><td>train_model_71304689</td><td style="text-align: right;">422.038 </td><td>True               </td></tr>
# <tr><td>train_model_7279d39b</td><td style="text-align: right;"> 43.8632</td><td>                   </td></tr>
# <tr><td>train_model_762f3c13</td><td style="text-align: right;">475.514 </td><td>True               </td></tr>
# <tr><td>train_model_7691ee2f</td><td style="text-align: right;">460.159 </td><td>True               </td></tr>
# <tr><td>train_model_7b4a5e15</td><td style="text-align: right;">473.705 </td><td>True               </td></tr>
# <tr><td>train_model_7bb3a3d5</td><td style="text-align: right;">470.808 </td><td>True               </td></tr>
# <tr><td>train_model_7e758a65</td><td style="text-align: right;">177.625 </td><td>                   </td></tr>
# <tr><td>train_model_834558e2</td><td style="text-align: right;">427.092 </td><td>True               </td></tr>
# <tr><td>train_model_855fb176</td><td style="text-align: right;">469.973 </td><td>True               </td></tr>
# <tr><td>train_model_87a6fe32</td><td style="text-align: right;">430.258 </td><td>True               </td></tr>
# <tr><td>train_model_88e1301e</td><td style="text-align: right;">473.753 </td><td>True               </td></tr>
# <tr><td>train_model_8928fa5a</td><td style="text-align: right;"> 85.5558</td><td>                   </td></tr>
# <tr><td>train_model_8dd22fb6</td><td style="text-align: right;">187.237 </td><td>                   </td></tr>
# <tr><td>train_model_8fd6b6ac</td><td style="text-align: right;">450.229 </td><td>True               </td></tr>
# <tr><td>train_model_9351b28e</td><td style="text-align: right;">221.331 </td><td>                   </td></tr>
# <tr><td>train_model_9586acf1</td><td style="text-align: right;"> 79.9553</td><td>                   </td></tr>
# <tr><td>train_model_95893fad</td><td style="text-align: right;"> 79.5904</td><td>True               </td></tr>
# <tr><td>train_model_96c99141</td><td style="text-align: right;">177.82  </td><td>                   </td></tr>
# <tr><td>train_model_97961339</td><td style="text-align: right;">422.286 </td><td>True               </td></tr>
# <tr><td>train_model_97fe24eb</td><td style="text-align: right;">474.999 </td><td>True               </td></tr>
# <tr><td>train_model_9866e230</td><td style="text-align: right;">474.481 </td><td>True               </td></tr>
# <tr><td>train_model_98b54a1d</td><td style="text-align: right;">363.395 </td><td>                   </td></tr>
# <tr><td>train_model_9a0203b3</td><td style="text-align: right;">152.132 </td><td>                   </td></tr>
# <tr><td>train_model_9a4c32d2</td><td style="text-align: right;"> 47.9995</td><td>                   </td></tr>
# <tr><td>train_model_9c19af0b</td><td style="text-align: right;">475.55  </td><td>True               </td></tr>
# <tr><td>train_model_a608d528</td><td style="text-align: right;">391.991 </td><td>True               </td></tr>
# <tr><td>train_model_a69f7211</td><td style="text-align: right;">474.847 </td><td>True               </td></tr>
# <tr><td>train_model_a716f822</td><td style="text-align: right;">387.505 </td><td>True               </td></tr>
# <tr><td>train_model_a7f63d99</td><td style="text-align: right;"> 82.4244</td><td>                   </td></tr>
# <tr><td>train_model_a89072eb</td><td style="text-align: right;"> 89.7748</td><td>                   </td></tr>
# <tr><td>train_model_a9afdda3</td><td style="text-align: right;">156.409 </td><td>                   </td></tr>
# <tr><td>train_model_ae19a51e</td><td style="text-align: right;">475.615 </td><td>True               </td></tr>
# <tr><td>train_model_ae915ea3</td><td style="text-align: right;">157.176 </td><td>                   </td></tr>
# <tr><td>train_model_b32f5d19</td><td style="text-align: right;">360.477 </td><td>True               </td></tr>
# <tr><td>train_model_b46b184d</td><td style="text-align: right;">174.702 </td><td>                   </td></tr>
# <tr><td>train_model_b4ae9bf3</
# (train_model pid=73107) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_d9df51b2_1_beta1=0.6498,beta2=0.9941,lr=0.0007,weight_decay=0.0060_2024-07-22_18-33-24/checkpoint_000000)
# (train_model pid=73107) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_d9df51b2_1_beta1=0.6498,beta2=0.9941,lr=0.0007,weight_decay=0.0060_2024-07-22_18-33-24/checkpoint_000001)
# (train_model pid=73107) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_d9df51b2_1_beta1=0.6498,beta2=0.9941,lr=0.0007,weight_decay=0.0060_2024-07-22_18-33-24/checkpoint_000002)
# (train_model pid=73107) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_d9df51b2_1_beta1=0.6498,beta2=0.9941,lr=0.0007,weight_decay=0.0060_2024-07-22_18-33-24/checkpoint_000003)
# (train_model pid=73107) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_d9df51b2_1_beta1=0.6498,beta2=0.9941,lr=0.0007,weight_decay=0.0060_2024-07-22_18-33-24/checkpoint_000004)
# (train_model pid=73107) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_d9df51b2_1_beta1=0.6498,beta2=0.9941,lr=0.0007,weight_decay=0.0060_2024-07-22_18-33-24/checkpoint_000005)
# (train_model pid=73107) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_d9df51b2_1_beta1=0.6498,beta2=0.9941,lr=0.0007,weight_decay=0.0060_2024-07-22_18-33-24/checkpoint_000006)
# (train_model pid=73107) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_d9df51b2_1_beta1=0.6498,beta2=0.9941,lr=0.0007,weight_decay=0.0060_2024-07-22_18-33-24/checkpoint_000007)
# (train_model pid=73107) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_d9df51b2_1_beta1=0.6498,beta2=0.9941,lr=0.0007,weight_decay=0.0060_2024-07-22_18-33-24/checkpoint_000008)
# (train_model pid=73107) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_d9df51b2_1_beta1=0.6498,beta2=0.9941,lr=0.0007,weight_decay=0.0060_2024-07-22_18-33-24/checkpoint_000009)
# (train_model pid=73107) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_d9df51b2_1_beta1=0.6498,beta2=0.9941,lr=0.0007,weight_decay=0.0060_2024-07-22_18-33-24/checkpoint_000010)
# (train_model pid=73107) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_d9df51b2_1_beta1=0.6498,beta2=0.9941,lr=0.0007,weight_decay=0.0060_2024-07-22_18-33-24/checkpoint_000011)
# (train_model pid=73107) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_d9df51b2_1_beta1=0.6498,beta2=0.9941,lr=0.0007,weight_decay=0.0060_2024-07-22_18-33-24/checkpoint_000012)
# (train_model pid=73107) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_d9df51b2_1_beta1=0.6498,beta2=0.9941,lr=0.0007,weight_decay=0.0060_2024-07-22_18-33-24/checkpoint_000013)
# (train_model pid=73107) Early stopping after 45 epochs
# (train_model pid=73107) Training complete.
# (train_model pid=73122) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_b8c739f0_3_beta1=0.7404,beta2=0.9701,lr=0.0000,weight_decay=0.0097_2024-07-22_18-33-32/checkpoint_000000) [repeated 6x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (train_model pid=73131) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_855fb176_5_beta1=0.6217,beta2=0.9520,lr=0.0004,weight_decay=0.0029_2024-07-22_18-33-41/checkpoint_000000) [repeated 2x across cluster]
# (train_model pid=73134) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_a69f7211_7_beta1=0.6824,beta2=0.9777,lr=0.0002,weight_decay=0.0051_2024-07-22_18-33-49/checkpoint_000000) [repeated 2x across cluster]
# (train_model pid=73140) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_9a4c32d2_9_beta1=0.5260,beta2=0.9939,lr=0.0010,weight_decay=0.0081_2024-07-22_18-33-56/checkpoint_000000) [repeated 3x across cluster]
# (train_model pid=73140) Early stopping after 37 epochs
# (train_model pid=73140) Training complete.
# (train_model pid=73149) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_0b76622f_11_beta1=0.6201,beta2=0.9629,lr=0.0001,weight_decay=0.0097_2024-07-22_18-34-07/checkpoint_000000) [repeated 16x across cluster]
# (train_model pid=73159) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_24b43512_13_beta1=0.8862,beta2=0.9471,lr=0.0007,weight_decay=0.0096_2024-07-22_18-34-15/checkpoint_000000) [repeated 2x across cluster]
# (train_model pid=73162) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_a7f63d99_15_beta1=0.5130,beta2=0.9990,lr=0.0010,weight_decay=0.0079_2024-07-22_18-34-24/checkpoint_000000) [repeated 4x across cluster]
# (train_model pid=73166) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_d85c1ae7_17_beta1=0.5258,beta2=0.9946,lr=0.0008,weight_decay=0.0080_2024-07-22_18-34-32/checkpoint_000000) [repeated 8x across cluster]
# (train_model pid=73167) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_a89072eb_18_beta1=0.5255,beta2=0.9943,lr=0.0010,weight_decay=0.0078_2024-07-22_18-34-36/checkpoint_000006) [repeated 14x across cluster]
# (train_model pid=73172) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_9866e230_20_beta1=0.5146,beta2=0.9987,lr=0.0002,weight_decay=0.0079_2024-07-22_18-34-44/checkpoint_000000) [repeated 2x across cluster]
# (train_model pid=73175) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_0192cadf_22_beta1=0.8498,beta2=0.9214,lr=0.0004,weight_decay=0.0066_2024-07-22_18-34-52/checkpoint_000000) [repeated 2x across cluster]
# (train_model pid=73178) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_d3bcbc4c_24_beta1=0.5396,beta2=0.9802,lr=0.0008,weight_decay=0.0098_2024-07-22_18-35-00/checkpoint_000000) [repeated 2x across cluster]
# (train_model pid=73183) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_1db83f38_26_beta1=0.5261,beta2=0.9931,lr=0.0005,weight_decay=0.0084_2024-07-22_18-35-08/checkpoint_000000) [repeated 3x across cluster]
# (train_model pid=73184) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_dedb2bf4_27_beta1=0.5124,beta2=0.9990,lr=0.0010,weight_decay=0.0079_2024-07-22_18-35-13/checkpoint_000005) [repeated 6x across cluster]
# (train_model pid=73189) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_b86d808f_29_beta1=0.5264,beta2=0.9943,lr=0.0010,weight_decay=0.0076_2024-07-22_18-35-21/checkpoint_000000) [repeated 3x across cluster]
# (train_model pid=73192) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_7691ee2f_31_beta1=0.5255,beta2=0.9944,lr=0.0005,weight_decay=0.0077_2024-07-22_18-35-29/checkpoint_000000) [repeated 4x across cluster]
# (train_model pid=73197) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_385955ad_33_beta1=0.5392,beta2=0.9803,lr=0.0005,weight_decay=0.0094_2024-07-22_18-35-38/checkpoint_000000) [repeated 3x across cluster]
# (train_model pid=73202) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_cd9c0388_35_beta1=0.5127,beta2=0.9990,lr=0.0010,weight_decay=0.0082_2024-07-22_18-35-46/checkpoint_000000) [repeated 2x across cluster]
# (train_model pid=73205) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_2191c4fe_37_beta1=0.6500,beta2=0.9944,lr=0.0008,weight_decay=0.0058_2024-07-22_18-35-54/checkpoint_000000) [repeated 4x across cluster]
# (train_model pid=73210) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_1ebfc7fe_39_beta1=0.5258,beta2=0.9942,lr=0.0010,weight_decay=0.0082_2024-07-22_18-36-02/checkpoint_000000) [repeated 3x across cluster]
# (train_model pid=73210) Early stopping after 31 epochs
# (train_model pid=73210) Training complete.
# (train_model pid=73213) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_544135fc_41_beta1=0.5258,beta2=0.9942,lr=0.0010,weight_decay=0.0082_2024-07-22_18-36-11/checkpoint_000000) [repeated 16x across cluster]
# (train_model pid=73213) Early stopping after 40 epochs
# (train_model pid=73213) Training complete.
# (train_model pid=73224) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_e712cd12_43_beta1=0.5507,beta2=0.9033,lr=0.0000,weight_decay=0.0072_2024-07-22_18-36-19/checkpoint_000000) [repeated 18x across cluster]
# (train_model pid=73227) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_5afba531_45_beta1=0.5396,beta2=0.9709,lr=0.0010,weight_decay=0.0100_2024-07-22_18-36-28/checkpoint_000000) [repeated 3x across cluster]
# (train_model pid=73231) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_7b4a5e15_47_beta1=0.6496,beta2=0.9940,lr=0.0003,weight_decay=0.0059_2024-07-22_18-36-37/checkpoint_000000) [repeated 4x across cluster]
# (train_model pid=73239) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_7279d39b_48_beta1=0.5263,beta2=0.9944,lr=0.0010,weight_decay=0.0083_2024-07-22_18-36-41/checkpoint_000004) [repeated 5x across cluster]
# (train_model pid=73239) Early stopping after 42 epochs
# (train_model pid=73239) Training complete.
# (train_model pid=73245) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_b4ae9bf3_50_beta1=0.5262,beta2=0.9943,lr=0.0010,weight_decay=0.0082_2024-07-22_18-36-50/checkpoint_000000) [repeated 13x across cluster]
# (train_model pid=73248) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_a716f822_52_beta1=0.5389,beta2=0.9704,lr=0.0008,weight_decay=0.0098_2024-07-22_18-36-58/checkpoint_000000) [repeated 3x across cluster]
# (train_model pid=73249) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_142c2955_53_beta1=0.5393,beta2=0.9706,lr=0.0010,weight_decay=0.0097_2024-07-22_18-37-02/checkpoint_000005) [repeated 6x across cluster]
# (train_model pid=73252) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_c9960040_55_beta1=0.5264,beta2=0.9944,lr=0.0010,weight_decay=0.0085_2024-07-22_18-37-11/checkpoint_000000) [repeated 4x across cluster]
# (train_model pid=73257) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_2b039a13_57_beta1=0.5265,beta2=0.9944,lr=0.0010,weight_decay=0.0082_2024-07-22_18-37-19/checkpoint_000000) [repeated 3x across cluster]
# (train_model pid=73259) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_be8bba82_59_beta1=0.6495,beta2=0.9938,lr=0.0008,weight_decay=0.0056_2024-07-22_18-37-27/checkpoint_000000) [repeated 8x across cluster]
# (train_model pid=73261) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_446cd54b_60_beta1=0.5264,beta2=0.9942,lr=0.0010,weight_decay=0.0083_2024-07-22_18-37-32/checkpoint_000006) [repeated 7x across cluster]
# (train_model pid=73266) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_8928fa5a_62_beta1=0.5258,beta2=0.9940,lr=0.0009,weight_decay=0.0081_2024-07-22_18-37-40/checkpoint_000000) [repeated 3x across cluster]
# (train_model pid=73279) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_f805d300_64_beta1=0.5257,beta2=0.9944,lr=0.0009,weight_decay=0.0080_2024-07-22_18-37-48/checkpoint_000000) [repeated 10x across cluster]
# (train_model pid=73281) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_00d4018c_65_beta1=0.5398,beta2=0.9801,lr=0.0010,weight_decay=0.0100_2024-07-22_18-37-53/checkpoint_000006) [repeated 7x across cluster]
# (train_model pid=73286) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_5b09acaf_67_beta1=0.5260,beta2=0.9941,lr=0.0010,weight_decay=0.0082_2024-07-22_18-38-01/checkpoint_000000) [repeated 2x across cluster]
# (train_model pid=73289) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_97961339_69_beta1=0.6498,beta2=0.9940,lr=0.0007,weight_decay=0.0060_2024-07-22_18-38-10/checkpoint_000000) [repeated 9x across cluster]
# (train_model pid=73296) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_834558e2_71_beta1=0.6497,beta2=0.9942,lr=0.0007,weight_decay=0.0060_2024-07-22_18-38-18/checkpoint_000000) [repeated 3x across cluster]
# (train_model pid=73298) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_95893fad_72_beta1=0.5260,beta2=0.9941,lr=0.0010,weight_decay=0.0080_2024-07-22_18-38-23/checkpoint_000005) [repeated 6x across cluster]
# (train_model pid=73299) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_9586acf1_73_beta1=0.5125,beta2=0.9990,lr=0.0010,weight_decay=0.0078_2024-07-22_18-38-27/checkpoint_000008) [repeated 11x across cluster]
# (train_model pid=73299) Early stopping after 41 epochs
# (train_model pid=73299) Training complete.
# (train_model pid=73302) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_55315b8a_75_beta1=0.6499,beta2=0.9941,lr=0.0008,weight_decay=0.0060_2024-07-22_18-38-35/checkpoint_000000) [repeated 8x across cluster]
# (train_model pid=73319) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_dc72ff9a_77_beta1=0.5255,beta2=0.9942,lr=0.0010,weight_decay=0.0078_2024-07-22_18-38-44/checkpoint_000000) [repeated 3x across cluster]
# (train_model pid=73326) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_8fd6b6ac_79_beta1=0.5132,beta2=0.9973,lr=0.0005,weight_decay=0.0079_2024-07-22_18-38-53/checkpoint_000000) [repeated 2x across cluster]
# (train_model pid=73330) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_ecd599da_81_beta1=0.5129,beta2=0.9990,lr=0.0010,weight_decay=0.0079_2024-07-22_18-39-01/checkpoint_000000) [repeated 2x across cluster]
# (train_model pid=73330) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_ecd599da_81_beta1=0.5129,beta2=0.9990,lr=0.0010,weight_decay=0.0079_2024-07-22_18-39-01/checkpoint_000015) [repeated 17x across cluster]
# (train_model pid=73330) Early stopping after 62 epochs
# (train_model pid=73330) Training complete.
# (train_model pid=73342) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_5f41ba04_84_beta1=0.5124,beta2=0.9989,lr=0.0009,weight_decay=0.0079_2024-07-22_18-39-14/checkpoint_000000) [repeated 4x across cluster]
# (train_model pid=73354) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_6070359d_86_beta1=0.7621,beta2=0.9162,lr=0.0006,weight_decay=0.0093_2024-07-22_18-39-23/checkpoint_000000) [repeated 8x across cluster]
# (train_model pid=73360) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_21d7f317_88_beta1=0.5258,beta2=0.9961,lr=0.0009,weight_decay=0.0066_2024-07-22_18-39-32/checkpoint_000000) [repeated 3x across cluster]
# (train_model pid=73363) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_b32f5d19_90_beta1=0.5393,beta2=0.9707,lr=0.0010,weight_decay=0.0096_2024-07-22_18-39-40/checkpoint_000000) [repeated 2x across cluster]
# (train_model pid=73373) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_25bc0192_92_beta1=0.5284,beta2=0.9935,lr=0.0006,weight_decay=0.0081_2024-07-22_18-39-49/checkpoint_000000) [repeated 3x across cluster]
# (train_model pid=73377) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_9a0203b3_94_beta1=0.5255,beta2=0.9960,lr=0.0009,weight_decay=0.0066_2024-07-22_18-39-58/checkpoint_000000) [repeated 2x across cluster]
# (train_model pid=73380) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_d1046d0d_96_beta1=0.5256,beta2=0.9960,lr=0.0010,weight_decay=0.0067_2024-07-22_18-40-07/checkpoint_000000) [repeated 3x across cluster]
# (train_model pid=73390) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_0c0c8d17_98_beta1=0.5136,beta2=0.9985,lr=0.0010,weight_decay=0.0084_2024-07-22_18-40-15/checkpoint_000000) [repeated 3x across cluster]
# (train_model pid=73399) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24/train_model_3541cb1d_100_beta1=0.6494,beta2=0.9943,lr=0.0009,weight_decay=0.0056_2024-07-22_18-40-24/checkpoint_000000) [repeated 3x across cluster]
# 2024-07-22 18:40:29,271	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/Users/hanheelee/ray_results/train_model_2024-07-22_18-33-24' in 0.0763s.
# 2024-07-22 18:40:29,305	INFO tune.py:1041 -- Total run time: 425.23 seconds (425.06 seconds for the tuning loop).
# /Users/hanheelee/Desktop/Projects/fuel-cell-AI/00_PyTorch/myvenv/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Users/hanheelee/Desktop/Projects/fuel-cell-AI/00_PyTorch/myvenv/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Users/hanheelee/Desktop/Projects/fuel-cell-AI/00_PyTorch/myvenv/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Users/hanheelee/Desktop/Projects/fuel-cell-AI/00_PyTorch/myvenv/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Users/hanheelee/Desktop/Projects/fuel-cell-AI/00_PyTorch/myvenv/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Users/hanheelee/Desktop/Projects/fuel-cell-AI/00_PyTorch/myvenv/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Users/hanheelee/Desktop/Projects/fuel-cell-AI/00_PyTorch/myvenv/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Users/hanheelee/Desktop/Projects/fuel-cell-AI/00_PyTorch/myvenv/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Users/hanheelee/Desktop/Projects/fuel-cell-AI/00_PyTorch/myvenv/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Users/hanheelee/Desktop/Projects/fuel-cell-AI/00_PyTorch/myvenv/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Users/hanheelee/Desktop/Projects/fuel-cell-AI/00_PyTorch/myvenv/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Users/hanheelee/Desktop/Projects/fuel-cell-AI/00_PyTorch/myvenv/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Best hyperparameters found were:  {'lr': 0.001, 'beta1': 0.5129358050730503, 'beta2': 0.999, 'weight_decay': 0.007947825232908604}
# Test MSE: 32.0295
# Test RMSE: 56.1351 Pa
# Relative Error: 11.85%
# R^2 Score: 0.9861
# Model and scalers are saved successfully.
